# %% [markdown]
# # Análise para todos os CSV's do mês

# %% [markdown]
# ## Importando bilbiotecas e todos os CSV's

# %%
import pandas as pd
import numpy as np
import glob

path = r'/home/cesar/Documents/freelas/csv' # use your path
all_files = glob.glob(path + "/*.csv")

# %% [markdown]
# ## Criando lista de DataFrames com todos os CSV's do mês

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, encoding="ISO-8859-1", sep=',', header=1)
    dados = df.iloc[6:,[0,1,2,3,4,5,6,7,8]]
    li.append(dados)

len(li)
# Out:
# 32

# %% [markdown]
# ## Replace das vírgulas, formatação das colunas, e criação de todos os describes

# %%
dataDescribedAll = []
for i in li:
    i['Label'] = pd.to_datetime(i['Label'])
    i['Ed0Gnd'] = i['Ed0Gnd'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0305'] = i['Ed0305'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0313'] = i['Ed0313'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0320'] = i['Ed0320'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0340'] = i['Ed0340'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0380'] = i['Ed0380'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0395'] = i['Ed0395'].replace('[^\d.]', '', regex=True).astype(float)
    i['Ed0PAR'] = i['Ed0PAR'].replace('[^\d.]', '', regex=True).astype(float)
    dataDescribedAll.append(i.describe().T)

# %%
dataDescribedAll[0]
# Out:
#          count       mean        std       min       25%       50%        75%  \
# Ed0Gnd  4319.0   2.164989   2.184340  0.000039  0.000044  0.000047   4.355050
# Ed0305  4319.0   2.087543   1.427696  0.001578  1.606250  1.789259   2.240211
# Ed0313  4319.0   4.618782   3.164056  0.000040  2.811885  3.487159   5.778149
# Ed0320  4319.0   8.290371   5.200071  0.001811  5.873447  6.766483   9.863161
# Ed0340  4319.0  11.750553  11.059024  0.002907  4.860926  5.459443  19.149555
# Ed0380  4319.0  14.657663  17.182699  0.006264  2.266529  4.212984  27.294950
# Ed0395  4319.0  15.247006  18.426389  0.000212  2.338959  3.095158  28.886640
# Ed0PAR  4319.0   3.483199   2.526689  0.002101  1.386044  3.121741   5.202959
#
#               max
# Ed0Gnd   4.805050
# Ed0305   9.920239
# Ed0313  12.409870
# Ed0320  20.591710
# Ed0340  36.676940
# Ed0380  51.663650
# Ed0395  54.576000
# Ed0PAR   9.996317

# %%
df2 = []
for i in range(len(li)):
    df2.append(pd.DataFrame(dataDescribedAll[i], columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']))
    df2[i]['Canais'] = ['Ed0Gnd','Ed0305','Ed0313','Ed0320','Ed0340','Ed0380','Ed0395','Ed0PAR']
df2[1]
# Out:
#          count       mean        std       min       25%       50%        75%  \
# Ed0Gnd  4319.0   2.162959   2.222785  0.000040  0.000044  0.000049   4.375050
# Ed0305  4319.0   2.168871   1.447012  0.001735  1.746741  1.947966   2.325039
# Ed0313  4319.0   4.577609   2.989240  0.009492  2.963004  3.616261   5.304794
# Ed0320  4319.0   7.769408   4.992700  0.000568  5.375259  6.153742   9.312250
# Ed0340  4319.0  11.064145  10.292690  0.001484  4.675527  5.288151  17.773605
# Ed0380  4319.0  13.666217  15.708662  0.001698  2.565772  4.188220  25.141885
# Ed0395  4319.0  14.183097  16.871885  0.000236  2.400060  3.155768  26.787775
# Ed0PAR  4319.0   4.641993   3.109643  0.001449  1.859170  4.579105   7.141315
#
#               max  Canais
# Ed0Gnd   5.015050  Ed0Gnd
# Ed0305   9.968001  Ed0305
# Ed0313  12.248630  Ed0313
# Ed0320  20.195410  Ed0320
# Ed0340  36.053360  Ed0340
# Ed0380  51.100760  Ed0380
# Ed0395  54.364350  Ed0395
# Ed0PAR   9.999539  Ed0PAR

# %% [markdown]
# ## Encontrando os máximos de todos os canais

# %%
#obtém os máximos e respectivos horários(horaMax)
a = []
b = []
c = []
d = []
e = []
f = []
g = []
h = []

for i in li:    
    a.append(i[['Label', 'Ed0Gnd']][i.Ed0Gnd == i.Ed0Gnd.max()])
    b.append(i[['Label', 'Ed0305']][i.Ed0305 == i.Ed0305.max()])
    c.append(i[['Label', 'Ed0313']][i.Ed0313 == i.Ed0313.max()])
    d.append(i[['Label', 'Ed0320']][i.Ed0320 == i.Ed0320.max()])
    e.append(i[['Label', 'Ed0340']][i.Ed0340 == i.Ed0340.max()])
    f.append(i[['Label', 'Ed0380']][i.Ed0380 == i.Ed0380.max()])
    g.append(i[['Label', 'Ed0395']][i.Ed0395 == i.Ed0395.max()])
    h.append(i[['Label', 'Ed0PAR']][i.Ed0PAR == i.Ed0PAR.max()])

for i in range(len(li)):
    a[i].drop_duplicates(subset ="Ed0Gnd", inplace = True)
    b[i].drop_duplicates(subset ="Ed0305", inplace = True)
    c[i].drop_duplicates(subset ="Ed0313", inplace = True)
    d[i].drop_duplicates(subset ="Ed0320", inplace = True)
    e[i].drop_duplicates(subset ="Ed0340", inplace = True)
    f[i].drop_duplicates(subset ="Ed0380", inplace = True)
    g[i].drop_duplicates(subset ="Ed0395", inplace = True)
    h[i].drop_duplicates(subset ="Ed0PAR", inplace = True)


#     finalA.append(a[i].drop)
    
    
# a[9].drop_duplicates(subset ="Ed0Gnd", inplace = True)
len(h)
# Out:
# 32

# %% [markdown]
# ## Cria novo DataFrame com Canal e horaMax

# %%
##### concatena o horaMax
horaMax = []
dataSet = []
canais = np.array(['Ed0Gnd','Ed0305','Ed0313','Ed0320','Ed0340','Ed0380','Ed0395','Ed0PAR'])

for i in range(len(li)):
    horaMax.append(pd.concat([a[i]['Label'], b[i]['Label'], c[i]['Label'], d[i]['Label'], e[i]['Label'], f[i]['Label'], g[i]['Label'], h[i]['Label']]))
    dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[i]}))

# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[0]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[1]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[2]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[3]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[4]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[5]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[6]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[7]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[8]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[9]})) -> ERRO!!!!!!!!!!!
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[10]}))
# dataSet.append(pd.DataFrame(data = {'Canal':canais, 'horaMax':horaMax[11]}))
dataSet[0]
# Out:
#        Canal             horaMax
# 3074  Ed0Gnd 2020-06-18 17:03:01
# 3443  Ed0305 2020-06-18 19:06:01
# 2702  Ed0313 2020-06-18 14:59:01
# 2701  Ed0320 2020-06-18 14:58:41
# 2701  Ed0340 2020-06-18 14:58:41
# 2701  Ed0380 2020-06-18 14:58:41
# 2701  Ed0395 2020-06-18 14:58:41
# 2258  Ed0PAR 2020-06-18 12:31:01

# %% [markdown]
# ## Mesclar os DataFrames

# %%
exportar = []

for i in range(len(li)):
    exportar.append(pd.merge(df2[i],dataSet[i], how='left', left_on=['Canais'], right_on=['Canal']))
exportar[31]
exportar[0]
fodase = pd.DataFrame(exportar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-0d0946f62c66> in <module>
#       5 exportar[31]
#       6 exportar[0]
# ----> 7 fodase = pd.DataFrame(exportar)
#       8 fodase
#
# ~/Documents/freelas/analiseRadiacoesSolares/venv_analise/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     521                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     522                 else:
# --> 523                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     524             else:
#     525                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~/Documents/freelas/analiseRadiacoesSolares/venv_analise/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     188     # by definition an array here
#     189     # the dtypes will be coerced to a single dtype
# --> 190     values = _prep_ndarray(values, copy=copy)
#     191
#     192     if dtype is not None:
#
# ~/Documents/freelas/analiseRadiacoesSolares/venv_analise/lib/python3.6/site-packages/pandas/core/internals/construction.py in _prep_ndarray(values, copy)
#     322         values = values.reshape((values.shape[0], 1))
#     323     elif values.ndim != 2:
# --> 324         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     325
#     326     return values
#
# ValueError: Must pass 2-d input. shape=(32, 8, 11)

# %% [markdown]
# ## Exportar os arquivos CSV's

# %%
#exporta o arquivo tratado
# for i in range(len(exportar)):
#     exportar[i].to_csv()
exportar.to_csv(r'/home/cesar/Documents/freelas/exportcsv/dados100.csv', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-4196651eb479> in <module>
#       2 # for i in range(len(exportar)):
#       3 #     exportar[i].to_csv()
# ----> 4 exportar.to_csv(r'/home/cesar/Documents/freelas/exportcsv/dados100.csv', index = False, header=True)
#
# AttributeError: 'list' object has no attribute 'to_csv'
